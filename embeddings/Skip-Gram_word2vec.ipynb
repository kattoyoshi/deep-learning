# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called __subsampling__ by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

def subsampling(int_words, threshold):
    '''
    # Arguments
        int_words: integer words vector
        threshold: frequency threshold
    # Return
        probability dictionary to discard each word
    '''
    total_count = len(int_words)
    word_counter = Counter(int_words)
    
    freq = {int_word : count/total_count for int_word, count in word_counter.items()}
    
    if threshold > max(freq.values()):
        assert Exception('threshold must be under {}'.format(max(freq.values())))
    
    p_drop = {ii: 1 - np.sqrt(threshold/freq[ii]) for ii in word_counter}
    
    return p_drop

p_drop = subsampling(int_words, 1e-5) 
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0 # out of index 対策
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1]) # set 型を使って重複は無視
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
# Number of the vocabulary
n_vocab = len(int_to_vocab)

# Number of embedding features 
n_embedding =  200 

with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w, 
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\yoshiyuki\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\ops\nn_impl.py:1346: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6735 0.0312 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6292 0.0238 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5171 0.0240 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6089 0.0241 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5116 0.0249 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5359 0.0249 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5777 0.0243 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5304 0.0236 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4833 0.0245 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4524 0.0248 sec/batch
# Nearest to there: zariski, radars, industrialized, tibetan, caf, detested, lunokhod, disarm,
# Nearest to has: foreground, medications, rameau, manetho, pixel, hennecke, january, countless,
# Nearest to a: discourse, broadway, pity, loading, gino, elfin, ocho, barren,
# Nearest to most: disseminate, graciously, raving, advantage, anegada, ru, setting, malo,
# Nearest to only: levy, galbraith, indicator, vellum, bracewell, steyr, anaximander, angevin,
# Nearest to be: cns, sultan, the, ipv, rear, lithium, marceau, corbijn,
# Nearest to so: demeanor, glossing, onto, longstanding, hinges, instead, destiny, squeeze,
# Nearest to as: close, resentments, heavy, moravia, ryukyu, gentiles, dde, hendrik,
# Nearest to institute: marries, santiago, buckskin, turbulence, stavropol, counsellor, prometaphase, blue,
# Nearest to experience: ellingham, awami, pasture, coaches, assimilation, georgians, powerlessness, parcham,
# Nearest to writers: edict, amd, mismanaged, optimistic, secretive, frf, sleeplessness, faulty,
# Nearest to older: opportunistic, pcmcia, towers, aloysius, reordered, treblinka, tland, glee,
# Nearest to consists: inquisitors, roofs, redemptive, ambush, pollute, statecraft, collett, opponents,
# Nearest to event: dharmakirti, oses, donner, blooming, huis, murdering, cinema, jagdish,
# Nearest to egypt: engler, smitten, ike, rollie, ztas, whiz, destruction, flammarion,
# Nearest to applications: vtol, larisa, southsea, italic, geometrical, boineburg, char, judas,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4891 0.0245 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3956 0.0250 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3309 0.0239 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2457 0.0243 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2106 0.0241 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1857 0.0242 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1127 0.0244 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0714 0.0250 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0028 0.0240 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9742 0.0243 sec/batch
# Nearest to there: zariski, industrialized, way, hours, radars, asserted, tibetan, possibly,
# Nearest to has: foreground, january, countless, special, medications, project, reunification, pixel,
# Nearest to a: discourse, loading, broadway, barren, word, index, gino, pity,
# Nearest to most: advantage, disseminate, setting, graciously, geographic, raving, daredevil, authorising,
# Nearest to only: indicator, levy, brutal, classics, vellum, legal, spawning, using,
# Nearest to be: sultan, cns, rear, the, cannot, divisions, addicts, ipv,
# Nearest to so: onto, demeanor, continues, glossing, instead, hinges, education, earth,
# Nearest to as: close, heavy, moravia, great, actual, mainly, from, indicate,
# Nearest to institute: santiago, marries, stavropol, buckskin, blue, miles, counsellor, prefectures,
# Nearest to experience: assimilation, repetitive, coaches, indigenous, georgians, expect, donohue, eberhard,
# Nearest to writers: edict, optimistic, no, mismanaged, secretive, the, lacks, amd,
# Nearest to older: opportunistic, reordered, aloysius, towers, months, ahead, pcmcia, beams,
# Nearest to consists: opponents, ambush, redemptive, statecraft, defense, fundamental, collett, finalized,
# Nearest to event: donner, dharmakirti, organize, huis, demand, oses, start, cinema,
# Nearest to egypt: engler, smitten, destruction, ike, perpetrator, grosseto, ztas, rollie,
# Nearest to applications: vtol, larisa, geometrical, italic, so, broken, receiving, southsea,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9466 0.0259 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9098 0.0237 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8905 0.0254 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8726 0.0240 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8237 0.0243 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8211 0.0242 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7853 0.0253 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8013 0.0250 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7882 0.0241 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7649 0.0240 sec/batch
# Nearest to there: zariski, industrialized, radars, caf, way, textile, tibetan, independence,
# Nearest to has: foreground, january, countless, medications, pixel, orthodoxy, conceive, echoes,
# Nearest to a: discourse, knox, barren, loading, broadway, elfin, produce, sebring,
# Nearest to most: advantage, disseminate, setting, graciously, ru, raving, psychiatry, surveying,
# Nearest to only: levy, indicator, brutal, galbraith, classics, coordinator, vellum, steyr,
# Nearest to be: sultan, cannot, cns, treasured, addicts, electro, rear, sportsman,
# Nearest to so: onto, demeanor, glossing, continues, hinges, destiny, concluding, instead,
# Nearest to as: close, moravia, resentments, rendition, indicate, heavy, gentiles, actual,
# Nearest to institute: santiago, marries, blue, buckskin, stavropol, miles, counsellor, prefectures,
# Nearest to experience: repetitive, assimilation, coaches, expect, pasture, indigenous, georgians, awami,
# Nearest to writers: edict, no, optimistic, secretive, mismanaged, faulty, vig, amd,
# Nearest to older: opportunistic, reordered, towers, aloysius, ahead, pcmcia, beams, tland,
# Nearest to consists: opponents, ambush, fundamental, roofs, statecraft, redemptive, depart, finalized,
# Nearest to event: donner, dharmakirti, organize, expresses, tendencies, cinema, huis, demand,
# Nearest to egypt: destruction, engler, smitten, grosseto, perpetrator, ztas, ike, follower,
# Nearest to applications: vtol, geometrical, larisa, judas, southsea, italic, so, velocity,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7825 0.0249 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7677 0.0237 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7260 0.0244 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7208 0.0231 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7523 0.0231 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6892 0.0236 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6825 0.0258 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7173 0.0245 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7036 0.0245 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6895 0.0237 sec/batch
# Nearest to there: zariski, radars, textile, industrialized, marquette, way, isolate, caf,
# Nearest to has: foreground, countless, pixel, medications, orthodoxy, echoes, fluids, withstand,
# Nearest to a: knox, barren, discourse, loading, jn, elfin, lab, benevolence,
# Nearest to most: disseminate, setting, advantage, graciously, raving, psychiatry, surveying, ru,
# Nearest to only: levy, indicator, galbraith, classics, vellum, slowdown, grunwald, brutal,
# Nearest to be: cannot, sportsman, addicts, sultan, electro, lithium, rear, treasured,
# Nearest to so: demeanor, onto, glossing, continues, squeeze, concluding, hinges, embodied,
# Nearest to as: moravia, close, ryukyu, resentments, rendition, indicate, actual, condemning,
# Nearest to institute: marries, santiago, stavropol, counsellor, blue, buckskin, miles, prefectures,
# Nearest to experience: pasture, assimilation, coaches, expect, awami, repetitive, ellingham, parcham,
# Nearest to writers: edict, no, secretive, mismanaged, vig, amd, mongols, optimistic,
# Nearest to older: opportunistic, reordered, aloysius, towers, pcmcia, hoppers, amazon, tland,
# Nearest to consists: statecraft, roofs, ambush, redemptive, collett, fundamental, sea, finalized,
# Nearest to event: organize, donner, dharmakirti, murdering, oses, tendencies, huis, cinema,
# Nearest to egypt: engler, destruction, smitten, ike, follower, perpetrator, grosseto, towel,
# Nearest to applications: vtol, geometrical, larisa, fingerprinting, judas, italic, southsea, so,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6537 0.0246 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6726 0.0253 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6170 0.0247 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6107 0.0254 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6362 0.0234 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6154 0.0227 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5907 0.0190 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5575 0.0239 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5081 0.0257 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5093 0.0237 sec/batch
# Nearest to there: zariski, radars, tibetan, lunokhod, trickery, textile, kook, way,
# Nearest to has: foreground, countless, medications, pixel, echoes, courtship, fluids, withstand,
# Nearest to a: knox, barren, discourse, sebring, jn, primitives, lab, loading,
# Nearest to most: disseminate, advantage, setting, raving, hindi, surveying, evolved, graciously,
# Nearest to only: indicator, levy, galbraith, slowdown, classics, fail, angevin, hex,
# Nearest to be: cannot, sportsman, lithium, addicts, electro, rear, amalgam, apple,
# Nearest to so: demeanor, onto, concluding, glossing, continues, squeeze, instead, hinges,
# Nearest to as: moravia, rendition, indicate, close, resentments, ryukyu, actual, overheat,
# Nearest to institute: marries, counsellor, stavropol, santiago, buckskin, blue, prefectures, miles,
# Nearest to experience: pasture, assimilation, expect, parcham, repetitive, coaches, ellingham, georgians,
# Nearest to writers: edict, secretive, no, optimistic, mismanaged, vig, amd, sleeplessness,
# Nearest to older: opportunistic, reordered, pcmcia, towers, ringing, aloysius, sixtus, hoppers,
# Nearest to consists: roofs, statecraft, collett, redemptive, ambush, fundamental, sea, finalized,
# Nearest to event: organize, donner, murdering, dharmakirti, oses, cinema, tendencies, huis,
# Nearest to egypt: engler, smitten, destruction, follower, towel, ike, grosseto, whiz,
# Nearest to applications: geometrical, vtol, fingerprinting, larisa, use, velocity, judas, southsea,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4909 0.0235 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4910 0.0243 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4625 0.0242 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4984 0.0239 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4911 0.0233 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5068 0.0239 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4354 0.0235 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4009 0.0238 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4117 0.0245 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4170 0.0251 sec/batch
# Nearest to there: zariski, radars, isolate, lunokhod, doubt, tibetan, identification, way,
# Nearest to has: foreground, medications, pixel, countless, nomen, courtship, bavarians, fluids,
# Nearest to a: sebring, compilers, waylon, knox, jn, discourse, word, stepwise,
# Nearest to most: setting, disseminate, advantage, raving, hindi, anegada, malo, evolved,
# Nearest to only: indicator, levy, galbraith, slowdown, shockwaves, grunwald, likewise, hex,
# Nearest to be: cannot, sportsman, sense, lithium, misled, rear, electro, addicts,
# Nearest to so: demeanor, onto, continues, squeeze, concluding, crystallized, instead, glossing,
# Nearest to as: moravia, indicate, close, actual, rendition, ryukyu, cursus, overheat,
# Nearest to institute: marries, counsellor, stavropol, santiago, prefectures, buckskin, blue, miles,
# Nearest to experience: expect, assimilation, pasture, parcham, georgians, picard, repetitive, ellingham,
# Nearest to writers: edict, no, secretive, septuagint, optimistic, sleeplessness, mismanaged, vig,
# Nearest to older: opportunistic, reordered, pcmcia, towers, ringing, diagram, aloysius, parseval,
# Nearest to consists: roofs, statecraft, countable, fundamental, finalized, sea, ambush, collett,
# Nearest to event: organize, murdering, tendencies, dharmakirti, donner, aural, regionally, webcast,
# Nearest to egypt: engler, smitten, destruction, towel, whiz, ike, eu, follower,
# Nearest to applications: geometrical, fingerprinting, vtol, use, velocity, circuit, larisa, motor,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4611 0.0263 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4188 0.0249 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4213 0.0245 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3871 0.0244 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4184 0.0244 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4571 0.0235 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3912 0.0247 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4004 0.0246 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4309 0.0245 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3444 0.0256 sec/batch
# Nearest to there: zariski, radars, isolate, lunokhod, identification, way, intensional, doubt,
# Nearest to has: foreground, medications, countless, pixel, oversight, manetho, in, conceive,
# Nearest to a: sebring, waylon, word, compilers, knox, primitives, percussion, buffaloes,
# Nearest to most: setting, advantage, disseminate, anegada, collaborations, raving, malo, evolved,
# Nearest to only: indicator, levy, slowdown, galbraith, hex, fail, shockwaves, grunwald,
# Nearest to be: cannot, sportsman, lithium, more, sense, misled, treasured, considerations,
# Nearest to so: demeanor, onto, concluding, embodied, instead, continues, crystallized, glossing,
# Nearest to as: actual, indicate, close, declensions, moravia, cursus, fully, rendition,
# Nearest to institute: counsellor, stavropol, marries, santiago, prefectures, blue, miles, buckskin,
# Nearest to experience: expect, assimilation, parcham, definability, pasture, repetitive, minimax, georgians,
# Nearest to writers: edict, medal, sleeplessness, septuagint, secretive, no, vig, optimistic,
# Nearest to older: opportunistic, reordered, pcmcia, towers, ringing, sixtus, cached, parseval,
# Nearest to consists: roofs, statecraft, countable, fundamental, finalized, collett, depart, erosion,
# Nearest to event: organize, tendencies, dharmakirti, aural, skill, regionally, demand, webcast,
# Nearest to egypt: engler, smitten, destruction, towel, ancient, eu, whiz, ike,
# Nearest to applications: geometrical, circuit, fingerprinting, device, hardware, vtol, interface, use,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3748 0.0257 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3953 0.0236 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3443 0.0246 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3344 0.0259 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3926 0.0244 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3606 0.0244 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3936 0.0244 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3754 0.0236 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3320 0.0245 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3479 0.0253 sec/batch
# Nearest to there: zariski, isolate, radars, lunokhod, way, kook, intensional, doubt,
# Nearest to has: foreground, medications, and, pixel, countless, in, investment, nomen,
# Nearest to a: sebring, primitives, sections, stepwise, jn, knox, compilers, wasted,
# Nearest to most: setting, advantage, hindi, evolved, raving, disseminate, anegada, collaborations,
# Nearest to only: slowdown, indicator, levy, galbraith, bracewell, shockwaves, hex, inri,
# Nearest to be: cannot, lithium, sportsman, misled, sense, considerations, rear, interceptors,
# Nearest to so: demeanor, onto, concluding, embodied, instead, continues, crystallized, meant,
# Nearest to as: indicate, actual, moravia, overheat, resentments, close, declensions, informers,
# Nearest to institute: counsellor, stavropol, marries, santiago, oxford, prefectures, elkhart, minefields,
# Nearest to experience: expect, violations, pasture, definability, repetitive, irrespective, assimilation, parcham,
# Nearest to writers: edict, septuagint, sleeplessness, medal, secretive, ideas, optimistic, vig,
# Nearest to older: opportunistic, reordered, pcmcia, diagram, towers, cached, households, schawlow,
# Nearest to consists: roofs, statecraft, countable, finalized, collett, depart, fundamental, sea,
# Nearest to event: organize, tendencies, aural, dharmakirti, regionally, murdering, skill, webcast,
# Nearest to egypt: smitten, engler, destruction, ancient, towel, eu, honduras, mszp,
# Nearest to applications: geometrical, circuit, vtol, fingerprinting, use, motor, device, larisa,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3290 0.0244 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2876 0.0249 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3836 0.0244 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3539 0.0252 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4056 0.0251 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3026 0.0250 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3194 0.0245 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3401 0.0251 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2164 0.0241 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2763 0.0243 sec/batch
# Nearest to there: zariski, isolate, lunokhod, radars, kook, intensional, doubt, way,
# Nearest to has: foreground, medications, investment, and, in, countless, manetho, pixel,
# Nearest to a: primitives, wasted, stepwise, sebring, knox, waylon, sections, jn,
# Nearest to most: setting, advantage, evolved, disseminate, malo, collaborations, hindi, surveying,
# Nearest to only: slowdown, levy, galbraith, indicator, shockwaves, hex, bracewell, cramped,
# Nearest to be: lithium, cannot, sense, planar, considerations, addicts, cns, rear,
# Nearest to so: demeanor, onto, concluding, embodied, crystallized, squeeze, continues, instead,
# Nearest to as: indicate, moravia, actual, overheat, resentments, flung, declensions, informers,
# Nearest to institute: counsellor, stavropol, oxford, santiago, elkhart, marries, prefectures, student,
# Nearest to experience: expect, minimax, parcham, definability, irrespective, punt, powerlessness, geonim,
# Nearest to writers: edict, septuagint, novelists, sleeplessness, medal, ideas, falun, vig,
# Nearest to older: opportunistic, reordered, towers, pcmcia, cached, diagram, reputedly, households,
# Nearest to consists: roofs, statecraft, finalized, depart, countable, collett, iodine, sea,
# Nearest to event: organize, tendencies, murdering, dharmakirti, aural, skill, webcast, regionally,
# Nearest to egypt: smitten, engler, ancient, destruction, towel, mszp, honduras, eu,
# Nearest to applications: vtol, use, interface, geometrical, circuit, fingerprinting, motor, smarteiffel,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2971 0.0247 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3032 0.0259 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3233 0.0132 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2467 0.0259 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2223 0.0249 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2151 0.0247 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2077 0.0254 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1996 0.0256 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2378 0.0240 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1679 0.0243 sec/batch
# Nearest to there: zariski, isolate, lunokhod, kook, radars, doubt, way, identification,
# Nearest to has: foreground, medications, pixel, and, in, countless, investment, ellipses,
# Nearest to a: sebring, stepwise, primitives, waylon, keeps, sections, wasted, outwards,
# Nearest to most: setting, evolved, advantage, disseminate, hindi, anegada, malo, collaborations,
# Nearest to only: slowdown, indicator, levy, galbraith, hex, under, shockwaves, cramped,
# Nearest to be: lithium, rear, cannot, planar, cns, interceptors, sense, treasured,
# Nearest to so: demeanor, concluding, onto, embodied, instead, crystallized, continues, squeeze,
# Nearest to as: indicate, close, actual, overheat, resentments, flung, moravia, floodgates,
# Nearest to institute: counsellor, stavropol, oxford, yale, elkhart, santiago, prefectures, academic,
# Nearest to experience: expect, repetitive, minimax, parcham, powerlessness, definability, irrespective, geonim,
# Nearest to writers: edict, novelists, septuagint, medal, ideas, sleeplessness, depicts, interlocutor,
# Nearest to older: reordered, opportunistic, age, householder, pcmcia, households, reputedly, towers,
# Nearest to consists: roofs, statecraft, countable, finalized, sea, iodine, depart, indirectly,
# Nearest to event: organize, murdering, aural, tendencies, dharmakirti, skill, webcast, regionally,
# Nearest to egypt: ancient, smitten, engler, destruction, towel, lydians, mszp, ike,
# Nearest to applications: vtol, interface, circuit, fingerprinting, use, gradients, phones, geometrical,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2216 0.0257 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2321 0.0247 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2215 0.0255 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1381 0.0259 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1836 0.0251 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1707 0.0264 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1769 0.0240 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1778 0.0254 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1917 0.0240 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1925 0.0245 sec/batch
# Nearest to there: zariski, isolate, lunokhod, radars, way, kook, doubt, tolerances,
# Nearest to has: foreground, medications, pixel, manetho, in, investment, countless, add,
# Nearest to a: sebring, primitives, keeps, sections, stepwise, outwards, does, wasted,
# Nearest to most: setting, evolved, disseminate, advantage, anegada, malo, collaborations, hindi,
# Nearest to only: slowdown, indicator, galbraith, levy, cramped, hex, likewise, bracewell,
# Nearest to be: lithium, cannot, planar, considerations, sense, papyrus, rear, interceptors,
# Nearest to so: demeanor, onto, embodied, debasing, concluding, squeeze, instead, crystallized,
# Nearest to as: indicate, actual, floodgates, overheat, moravia, simplest, fully, resentments,
# Nearest to institute: counsellor, oxford, stavropol, technology, academic, yale, student, elkhart,
# Nearest to experience: expect, repetitive, minimax, powerlessness, irrespective, definability, parcham, subtlety,
# Nearest to writers: edict, novelists, ideas, sleeplessness, interlocutor, medal, depicts, septuagint,
# Nearest to older: householder, age, households, reordered, opportunistic, reputedly, females, pcmcia,
# Nearest to consists: roofs, countable, finalized, statecraft, depart, strictly, categorization, mamayev,
# Nearest to event: organize, dharmakirti, tendencies, aural, murdering, trauma, webcast, skill,
# Nearest to egypt: ancient, smitten, destruction, engler, towel, lydians, mszp, ike,
# Nearest to applications: vtol, circuit, use, interface, smarteiffel, gradients, geometrical, phones,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1880 0.0251 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2400 0.0248 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1642 0.0257 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1612 0.0245 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2095 0.0247 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1805 0.0248 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2016 0.0244 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1789 0.0246 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1494 0.0250 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1509 0.0243 sec/batch
# Nearest to there: zariski, isolate, lunokhod, way, kook, doubt, radars, familes,
# Nearest to has: foreground, medications, pixel, in, manetho, and, investment, courtship,
# Nearest to a: of, primitives, sebring, sections, does, outwards, approximations, jn,
# Nearest to most: evolved, malo, disseminate, setting, anegada, upsets, collaborations, advantage,
# Nearest to only: indicator, levy, slowdown, bracewell, cramped, hex, likewise, all,
# Nearest to be: lithium, cannot, planar, papyrus, misled, considerations, sense, rear,
# Nearest to so: demeanor, onto, embodied, debasing, concluding, instead, crystallized, destiny,
# Nearest to as: actual, indicate, floodgates, simplest, fully, existence, flung, moravia,
# Nearest to institute: counsellor, oxford, stavropol, edu, student, technology, academic, enrollment,
# Nearest to experience: expect, minimax, repetitive, irrespective, subtlety, parcham, aldine, geonim,
# Nearest to writers: novelists, edict, ideas, medal, sleeplessness, liturgies, depicts, interlocutor,
# Nearest to older: householder, age, households, reordered, opportunistic, reputedly, pcmcia, females,
# Nearest to consists: roofs, countable, depart, statecraft, finalized, christian, categorization, mamayev,
# Nearest to event: organize, aural, tendencies, dharmakirti, incomplete, skill, webcast, trauma,
# Nearest to egypt: smitten, ancient, engler, destruction, towel, lydians, mszp, nubia,
# Nearest to applications: vtol, smarteiffel, evaluates, circuit, use, gradients, fingerprinting, geometrical,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1912 0.0250 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1598 0.0244 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1669 0.0253 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1874 0.0244 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1344 0.0243 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1253 0.0244 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1688 0.0246 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1250 0.0246 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1888 0.0248 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2128 0.0239 sec/batch
# Nearest to there: zariski, isolate, kook, lunokhod, doubt, migrations, way, radars,
# Nearest to has: foreground, medications, countless, pixel, manetho, in, and, courtship,
# Nearest to a: knox, of, rdr, in, jacobean, broadway, sebring, auditor,
# Nearest to most: evolved, malo, hindi, disseminate, advantage, intersexuality, anegada, setting,
# Nearest to only: slowdown, galbraith, likewise, indicator, cramped, all, levy, bracewell,
# Nearest to be: lithium, cannot, planar, misled, papyrus, sense, considerations, abusing,
# Nearest to so: demeanor, embodied, onto, anakin, debasing, concluding, crystallized, instead,
# Nearest to as: floodgates, moravia, the, actual, advertise, indicate, griswold, condemning,
# Nearest to institute: counsellor, oxford, student, stavropol, academic, edu, enrollment, yale,
# Nearest to experience: expect, minimax, parcham, coaches, aldine, powerlessness, irrespective, picard,
# Nearest to writers: novelists, edict, ideas, liturgies, medal, sleeplessness, falun, depicts,
# Nearest to older: householder, age, households, reordered, reputedly, opportunistic, pcmcia, females,
# Nearest to consists: roofs, countable, finalized, depart, statecraft, categorization, carlito, mamayev,
# Nearest to event: organize, aural, tendencies, dharmakirti, murdering, incomplete, trauma, skill,
# Nearest to egypt: ancient, smitten, destruction, engler, mszp, nubia, towel, lydians,
# Nearest to applications: vtol, smarteiffel, evaluates, programs, interface, circuit, gradients, phones,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2329 0.0261 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1259 0.0250 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1423 0.0248 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1585 0.0252 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0304 0.0248 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1555 0.0259 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1236 0.0255 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1213 0.0242 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1789 0.0060 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1136 0.0241 sec/batch
# Nearest to there: zariski, isolate, kook, lunokhod, radars, way, familes, doubt,
# Nearest to has: foreground, medications, pixel, and, in, countless, developed, investment,
# Nearest to a: of, in, sebring, philby, does, primitives, is, approximations,
# Nearest to most: advantage, evolved, disseminate, vibrates, intersexuality, setting, hindi, malo,
# Nearest to only: likewise, cramped, indicator, galbraith, slowdown, levy, all, assume,
# Nearest to be: lithium, planar, cannot, misled, papyrus, cns, considerations, sense,
# Nearest to so: demeanor, onto, embodied, debasing, anakin, concluding, crystallized, instead,
# Nearest to as: floodgates, actual, organometallic, heavy, griswold, indicate, flung, often,
# Nearest to institute: counsellor, oxford, student, stavropol, academic, enrollment, alumni, edu,
# Nearest to experience: expect, minimax, roundaboutness, irrespective, aldine, repetitive, parcham, picard,
# Nearest to writers: novelists, edict, liturgies, ideas, depicts, medal, falun, interlocutor,
# Nearest to older: householder, households, age, reordered, reputedly, opportunistic, pcmcia, diagram,
# Nearest to consists: roofs, depart, finalized, countable, statecraft, raeben, mamayev, categorization,
# Nearest to event: organize, murdering, incomplete, aural, waved, dharmakirti, fashions, tendencies,
# Nearest to egypt: ancient, smitten, lydians, destruction, towel, engler, mszp, nubia,
# Nearest to applications: vtol, smarteiffel, use, evaluates, programs, interface, larisa, ocaml,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0837 0.0247 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0661 0.0246 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0869 0.0242 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0505 0.0246 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0699 0.0253 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0595 0.0252 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1068 0.0248 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0915 0.0248 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1185 0.0248 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9935 0.0251 sec/batch
# Nearest to there: isolate, zariski, kook, lunokhod, doubt, familes, radars, ow,
# Nearest to has: foreground, medications, pixel, in, and, developed, investment, countless,
# Nearest to a: in, of, and, first, sebring, the, philby, with,
# Nearest to most: disseminate, evolved, advantage, malo, hindi, setting, vibrates, anegada,
# Nearest to only: likewise, all, cramped, levy, is, ballplayers, galbraith, indicator,
# Nearest to be: lithium, cannot, planar, rear, papyrus, considerations, abusing, electromyography,
# Nearest to so: demeanor, onto, debasing, anakin, embodied, crystallized, instead, concluding,
# Nearest to as: floodgates, the, heavy, griswold, more, moravia, often, throw,
# Nearest to institute: counsellor, student, stavropol, oxford, enrollment, academic, edu, elkhart,
# Nearest to experience: expect, minimax, irrespective, roundaboutness, aldine, repetitive, coaches, geonim,
# Nearest to writers: novelists, edict, liturgies, medal, ideas, depicts, interlocutor, falun,
# Nearest to older: householder, age, households, reordered, reputedly, opportunistic, pcmcia, income,
# Nearest to consists: roofs, depart, countable, finalized, statecraft, categorization, mamayev, nans,
# Nearest to event: organize, murdering, skill, incomplete, aural, tendencies, waved, fashions,
# Nearest to egypt: ancient, smitten, lydians, destruction, towel, mszp, nubia, engler,
# Nearest to applications: vtol, smarteiffel, evaluates, use, programs, interface, phones, circuit,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0269 0.0255 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0377 0.0244 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9997 0.0243 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0652 0.0246 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0631 0.0246 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0531 0.0242 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0661 0.0250 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0991 0.0240 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0338 0.0249 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0252 0.0243 sec/batch
# Nearest to there: zariski, isolate, kook, way, quaoar, hive, doubt, radars,
# Nearest to has: foreground, medications, in, pixel, and, manetho, cis, multiracial,
# Nearest to a: of, in, and, is, does, the, that, first,
# Nearest to most: disseminate, evolved, advantage, have, hindi, vibrates, anegada, intersexuality,
# Nearest to only: likewise, is, all, cramped, ballplayers, hex, indicator, assume,
# Nearest to be: lithium, cannot, planar, electromyography, considerations, papyrus, misled, sense,
# Nearest to so: demeanor, debasing, onto, anakin, embodied, crystallized, concluding, porosity,
# Nearest to as: floodgates, the, griswold, organometallic, actual, orchestral, heavy, more,
# Nearest to institute: counsellor, student, enrollment, oxford, technology, stavropol, edu, alumni,
# Nearest to experience: expect, minimax, irrespective, sensations, aldine, repetitive, roundaboutness, pasture,
# Nearest to writers: novelists, edict, medal, liturgies, depicts, ideas, fiction, interlocutor,
# Nearest to older: householder, age, households, reordered, reputedly, opportunistic, females, pcmcia,
# Nearest to consists: roofs, depart, countable, finalized, mamayev, nans, categorization, statecraft,
# Nearest to event: organize, tendencies, aural, incomplete, murdering, webcast, waved, trauma,
# Nearest to egypt: ancient, smitten, lydians, towel, destruction, nubia, mszp, ztas,
# Nearest to applications: vtol, smarteiffel, evaluates, use, circuit, interface, programs, semiconductors,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0388 0.0269 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0652 0.0235 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0826 0.0250 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0281 0.0254 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0681 0.0245 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0492 0.0247 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0537 0.0240 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0541 0.0254 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0860 0.0251 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0772 0.0243 sec/batch
# Nearest to there: kook, zariski, isolate, way, lunokhod, doubt, hive, thereof,
# Nearest to has: foreground, medications, pixel, in, and, cis, multiracial, presentations,
# Nearest to a: of, and, in, first, the, is, archontology, by,
# Nearest to most: advantage, hindi, disseminate, evolved, malo, anegada, vibrates, arnold,
# Nearest to only: is, likewise, all, cramped, when, ballplayers, levy, galbraith,
# Nearest to be: lithium, planar, cannot, papyrus, considerations, frauds, sense, misled,
# Nearest to so: demeanor, debasing, embodied, onto, anakin, concluding, crystallized, instead,
# Nearest to as: the, floodgates, griswold, heavy, condemning, century, advertise, resentments,
# Nearest to institute: counsellor, oxford, enrollment, stavropol, edu, student, elkhart, technology,
# Nearest to experience: expect, irrespective, minimax, aldine, roundaboutness, parcham, sensations, pasture,
# Nearest to writers: novelists, medal, edict, depicts, fiction, liturgies, ideas, sleeplessness,
# Nearest to older: householder, age, households, reordered, income, reputedly, females, opportunistic,
# Nearest to consists: roofs, depart, countable, finalized, nans, categorization, mamayev, statecraft,
# Nearest to event: organize, tendencies, aural, incomplete, murdering, webcast, waved, fashions,
# Nearest to egypt: ancient, smitten, nubia, towel, destruction, lydians, ztas, mszp,
# Nearest to applications: vtol, smarteiffel, use, evaluates, programs, geometrical, semiconductors, phones,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0299 0.0252 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9947 0.0247 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0429 0.0239 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0653 0.0246 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0803 0.0240 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1206 0.0230 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1248 0.0233 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0540 0.0235 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0709 0.0241 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0524 0.0238 sec/batch
# Nearest to there: isolate, zariski, kook, kuwaiti, familes, ow, hive, doubt,
# Nearest to has: foreground, pixel, medications, and, in, cis, multiracial, sativa,
# Nearest to a: of, in, and, the, is, that, by, first,
# Nearest to most: disseminate, advantage, vibrates, hindi, connemara, arnold, intersexuality, have,
# Nearest to only: likewise, galbraith, is, ballplayers, all, when, levy, cramped,
# Nearest to be: lithium, planar, cannot, papyrus, misled, frauds, considerations, electromyography,
# Nearest to so: demeanor, onto, anakin, debasing, embodied, crystallized, concluding, squeeze,
# Nearest to as: the, floodgates, griswold, heavy, orchestral, often, century, organometallic,
# Nearest to institute: counsellor, oxford, enrollment, stavropol, technology, edu, student, elkhart,
# Nearest to experience: minimax, irrespective, roundaboutness, expect, sensations, aldine, ryder, pasture,
# Nearest to writers: novelists, medal, edict, fiction, births, depicts, liturgies, vig,
# Nearest to older: householder, age, households, income, females, reputedly, reordered, males,
# Nearest to consists: roofs, depart, countable, finalized, nans, categorization, carlito, raeben,
# Nearest to event: organize, tendencies, aural, waved, incomplete, webcast, murdering, fashions,
# Nearest to egypt: ancient, smitten, nubia, towel, lydians, destruction, ztas, mszp,
# Nearest to applications: vtol, smarteiffel, evaluates, use, programs, larisa, interface, phones,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9674 0.0246 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0489 0.0239 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0424 0.0232 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0589 0.0244 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0808 0.0249 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0320 0.0239 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0145 0.0265 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9906 0.0254 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0259 0.0256 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9712 0.0252 sec/batch
# Nearest to there: isolate, zariski, kook, southern, hive, kuwaiti, thereof, familes,
# Nearest to has: foreground, pixel, medications, cis, and, multiracial, countless, sativa,
# Nearest to a: in, the, and, of, is, with, diminishes, first,
# Nearest to most: disseminate, hindi, advantage, intersexuality, vibrates, have, connemara, arnold,
# Nearest to only: likewise, is, all, ballplayers, cramped, assume, galbraith, when,
# Nearest to be: lithium, planar, cannot, papyrus, considerations, misled, electromyography, mokhehle,
# Nearest to so: demeanor, debasing, anakin, embodied, onto, concluding, crystallized, instead,
# Nearest to as: the, griswold, heavy, floodgates, organometallic, often, orchestral, more,
# Nearest to institute: stavropol, enrollment, counsellor, oxford, elkhart, student, technology, yale,
# Nearest to experience: minimax, irrespective, roundaboutness, expect, aldine, sensations, pasture, repetitive,
# Nearest to writers: novelists, medal, fiction, depicts, edict, liturgies, births, falun,
# Nearest to older: householder, age, households, reordered, income, reputedly, females, opportunistic,
# Nearest to consists: roofs, depart, countable, finalized, nans, categorization, raeben, carlito,
# Nearest to event: organize, aural, tendencies, incomplete, murdering, webcast, waved, fashions,
# Nearest to egypt: ancient, smitten, nubia, lydians, towel, destruction, ztas, explicate,
# Nearest to applications: vtol, smarteiffel, programs, evaluates, use, interface, larisa, spar,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9803 0.0257 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9536 0.0234 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0360 0.0249 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0039 0.0251 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0210 0.0233 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9722 0.0242 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8986 0.0250 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9817 0.0238 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9266 0.0245 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9996 0.0249 sec/batch
# Nearest to there: isolate, zariski, kook, familes, hive, doubt, quaoar, are,
# Nearest to has: foreground, pixel, medications, and, in, cis, multiracial, bangladeshi,
# Nearest to a: and, is, in, the, of, first, for, with,
# Nearest to most: vibrates, advantage, anegada, have, hindi, disseminate, ruiz, connemara,
# Nearest to only: is, ballplayers, likewise, all, galbraith, when, to, even,
# Nearest to be: lithium, planar, cannot, papyrus, electromyography, iterations, considerations, equivocation,
# Nearest to so: demeanor, anakin, porosity, debasing, onto, crystallized, it, embodied,
# Nearest to as: the, heavy, floodgates, and, from, more, both, league,
# Nearest to institute: enrollment, technology, stavropol, oxford, counsellor, elkhart, student, yale,
# Nearest to experience: minimax, roundaboutness, irrespective, expect, aldine, sensations, repetitive, pasture,
# Nearest to writers: novelists, depicts, medal, edict, liturgies, fiction, aberystwyth, births,
# Nearest to older: householder, age, households, income, females, median, reputedly, reordered,
# Nearest to consists: depart, roofs, finalized, countable, nans, categorization, sesotho, enol,
# Nearest to event: organize, aural, tendencies, incomplete, webcast, waved, start, scale,
# Nearest to egypt: ancient, nubia, smitten, lydians, towel, ztas, destruction, engler,
# Nearest to applications: vtol, smarteiffel, evaluates, use, semiconductors, programs, larisa, italic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0067 0.0262 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9597 0.0250 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0011 0.0247 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0022 0.0253 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0211 0.0239 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9395 0.0246 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9659 0.0248 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9838 0.0251 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0074 0.0243 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9934 0.0240 sec/batch
# Nearest to there: isolate, zariski, kook, are, every, quaoar, hive, way,
# Nearest to has: medications, pixel, foreground, and, in, cis, multiracial, manetho,
# Nearest to a: of, and, in, is, the, first, by, for,
# Nearest to most: arnold, vibrates, ruiz, advantage, disseminate, have, between, anegada,
# Nearest to only: is, likewise, ballplayers, all, when, to, categories, even,
# Nearest to be: cannot, lithium, planar, papyrus, electromyography, considerations, equivocation, iterations,
# Nearest to so: demeanor, debasing, anakin, onto, embodied, it, porosity, concluding,
# Nearest to as: the, heavy, floodgates, more, griswold, orchestral, and, both,
# Nearest to institute: technology, enrollment, stavropol, oxford, elkhart, counsellor, yale, student,
# Nearest to experience: minimax, aldine, sensations, incarnate, roundaboutness, expect, irrespective, pasture,
# Nearest to writers: novelists, medal, depicts, fiction, edict, liturgies, secretive, aberystwyth,
# Nearest to older: householder, age, households, income, females, median, reputedly, reordered,
# Nearest to consists: depart, countable, roofs, finalized, nans, carlito, raeben, categorization,
# Nearest to event: organize, aural, tendencies, incomplete, webcast, scale, depreciation, start,
# Nearest to egypt: ancient, nubia, smitten, lydians, towel, ztas, explicate, mszp,
# Nearest to applications: vtol, smarteiffel, evaluates, programs, use, semiconductors, interface, imaging,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0227 0.0257 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9723 0.0242 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9861 0.0252 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9832 0.0245 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0246 0.0250 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9986 0.0243 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9904 0.0253 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9518 0.0252 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9572 0.0252 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0527 0.0254 sec/batch
# Nearest to there: isolate, kook, hive, zariski, are, maximise, every, thereof,
# Nearest to has: pixel, medications, in, and, foreground, cis, multiracial, manetho,
# Nearest to a: in, and, of, the, is, first, by, for,
# Nearest to most: hindi, negroes, between, advantage, have, vibrates, the, arnold,
# Nearest to only: is, when, likewise, all, to, not, ballplayers, even,
# Nearest to be: lithium, cannot, papyrus, planar, frauds, shriner, electromyography, underrepresented,
# Nearest to so: demeanor, debasing, embodied, anakin, crystallized, porosity, onto, squeeze,
# Nearest to as: the, heavy, floodgates, griswold, and, more, both, league,
# Nearest to institute: elkhart, stavropol, counsellor, oxford, yale, technology, postgraduate, enrollment,
# Nearest to experience: minimax, aldine, roundaboutness, sensations, incarnate, pasture, irrespective, expect,
# Nearest to writers: novelists, medal, edict, depicts, liturgies, fiction, aberystwyth, deaths,
# Nearest to older: householder, age, households, females, income, median, males, reputedly,
# Nearest to consists: depart, finalized, countable, roofs, carlito, categorization, sesotho, indirectly,
# ...
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7932 0.0226 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8122 0.0226 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7769 0.0243 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8447 0.0237 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8594 0.0252 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8284 0.0242 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8541 0.0243 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8859 0.0241 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8872 0.0244 sec/batch
# Nearest to there: are, is, if, have, every, not, kuwaiti, kook,
# Nearest to has: in, and, as, of, been, is, pixel, several,
# Nearest to a: the, in, and, is, of, first, for, with,
# Nearest to most: in, the, as, and, have, is, during, an,
# Nearest to only: is, not, the, as, first, to, in, a,
# Nearest to be: is, of, cannot, or, a, which, it, if,
# Nearest to so: it, not, even, to, sufficient, is, pot, squeeze,
# Nearest to as: the, in, and, is, a, of, such, more,
# Nearest to institute: technology, elkhart, roslin, postgraduate, stavropol, universities, racket, oxford,
# Nearest to experience: pasture, preparation, sensations, ruska, appropriate, roundaboutness, gebhard, generalized,
# Nearest to writers: novelists, fiction, winners, secretive, polymaths, imposing, medal, dramatists,
# Nearest to older: age, householder, females, couples, households, median, alone, someone,
# Nearest to consists: magisterial, finalized, archaebacteria, invalidated, carlito, each, jumper, chancery,
# Nearest to event: organize, events, incomplete, tendencies, start, aural, glaciations, waved,
# Nearest to egypt: nubia, ancient, egyptologist, greece, curator, lydians, ztas, cairo,
# Nearest to applications: vtol, wilber, smarteiffel, semiconductors, evaluates, conductivity, energetics, italic,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8080 0.0249 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8539 0.0237 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8427 0.0242 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8494 0.0238 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8709 0.0236 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8776 0.0235 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8225 0.0234 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8393 0.0232 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8632 0.0228 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8909 0.0237 sec/batch
# Nearest to there: are, every, if, have, is, kuwaiti, not, currently,
# Nearest to has: in, pixel, and, as, been, is, the, of,
# Nearest to a: in, the, and, of, is, first, with, for,
# Nearest to most: in, the, as, during, and, by, have, such,
# Nearest to only: is, not, as, in, the, first, a, all,
# Nearest to be: a, or, is, cannot, of, which, it, but,
# Nearest to so: it, not, to, sufficient, even, squeeze, crystallized, pot,
# Nearest to as: the, a, in, is, and, such, more, only,
# Nearest to institute: technology, elkhart, roslin, postgraduate, stavropol, racket, universities, oxford,
# Nearest to experience: pasture, preparation, ruska, malcom, gebhard, hester, sensations, roundaboutness,
# Nearest to writers: novelists, fiction, winners, polymaths, secretive, dramatists, depicts, imposing,
# Nearest to older: age, householder, females, couples, households, median, families, alone,
# Nearest to consists: each, finalized, magisterial, archaebacteria, jumper, carlito, establishes, invalidated,
# Nearest to event: events, organize, incomplete, tendencies, start, aural, glaciations, scale,
# Nearest to egypt: nubia, ancient, lydians, cairo, greece, egyptologist, egyptian, curator,
# Nearest to applications: vtol, wilber, smarteiffel, evaluates, programs, italic, conductivity, semiconductors,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8807 0.0243 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8419 0.0243 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8341 0.0245 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8474 0.0242 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9214 0.0234 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8580 0.0237 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9578 0.0244 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9235 0.0229 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8818 0.0238 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8270 0.0236 sec/batch
# Nearest to there: are, not, have, every, if, is, kuwaiti, no,
# Nearest to has: in, been, and, as, is, pixel, the, of,
# Nearest to a: in, the, of, is, and, as, with, for,
# Nearest to most: in, the, as, during, by, and, is, have,
# Nearest to only: not, as, is, all, first, in, the, while,
# Nearest to be: or, is, but, a, cannot, it, which, example,
# Nearest to so: it, not, squeeze, even, sufficient, crystallized, is, pot,
# Nearest to as: the, a, in, is, and, such, have, of,
# Nearest to institute: technology, elkhart, roslin, postgraduate, racket, stavropol, oxford, universities,
# Nearest to experience: ruska, gebhard, preparation, malcom, sensations, psychotherapy, pasture, midland,
# Nearest to writers: novelists, fiction, winners, polymaths, secretive, dramatists, imposing, depicts,
# Nearest to older: age, householder, females, median, households, alone, couples, someone,
# Nearest to consists: finalized, magisterial, each, jumper, carlito, archaebacteria, invalidated, countable,
# Nearest to event: events, organize, incomplete, tendencies, start, aural, glaciations, webcast,
# Nearest to egypt: nubia, ancient, curator, lydians, ike, cairo, egyptologist, greece,
# Nearest to applications: vtol, wilber, smarteiffel, evaluates, programs, conductivity, energetics, use,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8266 0.0241 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8280 0.0237 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8094 0.0231 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8682 0.0243 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8387 0.0248 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8562 0.0248 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8524 0.0184 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8622 0.0229 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8080 0.0229 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8714 0.0232 sec/batch
# Nearest to there: are, is, every, have, if, not, kuwaiti, only,
# Nearest to has: been, as, pixel, is, in, and, several, some,
# Nearest to a: in, the, and, of, is, for, with, as,
# Nearest to most: the, as, is, in, are, such, and, an,
# Nearest to only: not, is, the, all, as, first, in, but,
# Nearest to be: or, a, is, if, but, cannot, to, it,
# Nearest to so: it, not, even, to, squeeze, crystallized, sufficient, debasing,
# Nearest to as: the, and, in, a, is, such, most, of,
# Nearest to institute: technology, roslin, elkhart, stavropol, racket, postgraduate, oxford, uploaded,
# Nearest to experience: psychotherapy, ruska, gebhard, sensations, preparation, appropriate, malcom, worldly,
# Nearest to writers: novelists, fiction, winners, secretive, polymaths, imposing, dramatists, nebula,
# Nearest to older: age, householder, households, females, median, alone, couples, families,
# Nearest to consists: each, magisterial, archaebacteria, finalized, jumper, barrington, divided, invalidated,
# Nearest to event: events, organize, incomplete, aural, start, tendencies, webcast, glaciations,
# Nearest to egypt: nubia, ancient, cairo, egyptologist, curator, lydians, narmer, giza,
# Nearest to applications: wilber, vtol, smarteiffel, evaluates, italic, dilute, conductivity, energetics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7888 0.0249 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8518 0.0237 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7686 0.0245 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8732 0.0241 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8400 0.0246 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8732 0.0232 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8753 0.0232 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7484 0.0229 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8069 0.0245 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7587 0.0240 sec/batch
# Nearest to there: are, is, not, have, if, every, known, that,
# Nearest to has: in, is, as, been, and, the, for, of,
# Nearest to a: in, the, is, and, of, for, as, with,
# Nearest to most: in, the, as, is, and, are, by, during,
# Nearest to only: not, is, all, the, as, first, in, to,
# Nearest to be: is, a, or, which, are, it, example, cannot,
# Nearest to so: it, not, to, even, squeeze, sufficient, is, debasing,
# Nearest to as: the, in, a, and, is, most, from, of,
# Nearest to institute: technology, roslin, elkhart, stavropol, postgraduate, universities, racket, oxford,
# Nearest to experience: sensations, preparation, worldly, ruska, appropriate, psychotherapy, galen, gebhard,
# Nearest to writers: novelists, fiction, winners, secretive, imposing, polymaths, dramatists, undeciphered,
# Nearest to older: age, householder, median, females, households, alone, someone, couples,
# Nearest to consists: each, magisterial, finalized, archaebacteria, divided, are, main, staggered,
# Nearest to event: events, organize, incomplete, tendencies, aural, start, webcast, donner,
# Nearest to egypt: nubia, ancient, cairo, giza, egyptologist, curator, ike, narmer,
# Nearest to applications: wilber, vtol, smarteiffel, evaluates, conductivity, italic, oxide, dilute,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7650 0.0254 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8451 0.0240 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8517 0.0238 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8520 0.0245 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8362 0.0237 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9179 0.0240 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8136 0.0232 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8052 0.0246 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8256 0.0233 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8311 0.0245 sec/batch
# Nearest to there: are, have, every, is, if, not, substantially, kuwaiti,
# Nearest to has: been, in, is, as, of, and, pixel, the,
# Nearest to a: in, the, of, is, and, as, for, with,
# Nearest to most: in, the, as, during, is, are, and, some,
# Nearest to only: not, is, all, first, the, to, in, as,
# Nearest to be: a, or, is, of, which, but, to, it,
# Nearest to so: it, not, to, squeeze, sufficient, is, debasing, even,
# Nearest to as: the, in, a, and, is, of, such, more,
# Nearest to institute: technology, roslin, elkhart, racket, postgraduate, stavropol, research, backplane,
# Nearest to experience: sensations, worldly, preparation, pasture, ruska, dhyana, appropriate, psychotherapy,
# Nearest to writers: novelists, fiction, winners, secretive, polymaths, dramatists, imposing, nebula,
# Nearest to older: age, householder, females, median, alone, households, size, couples,
# Nearest to consists: each, magisterial, finalized, archaebacteria, barrington, main, invalidated, divided,
# Nearest to event: events, organize, incomplete, start, tendencies, aural, webcast, donner,
# Nearest to egypt: nubia, cairo, ike, curator, narmer, giza, ancient, egyptologist,
# Nearest to applications: wilber, vtol, smarteiffel, evaluates, italic, conductivity, energetics, semiconductors,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8545 0.0241 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8644 0.0240 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8392 0.0245 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8241 0.0241 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8644 0.0243 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8382 0.0234 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8721 0.0235 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8398 0.0233 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7954 0.0253 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8316 0.0232 sec/batch
# Nearest to there: are, have, is, not, every, if, maximise, no,
# Nearest to has: in, been, as, and, is, for, some, an,
# Nearest to a: in, the, of, is, and, as, for, with,
# Nearest to most: in, the, as, during, is, by, some, are,
# Nearest to only: not, as, is, in, all, a, the, but,
# Nearest to be: a, or, is, it, but, in, which, to,
# Nearest to so: it, not, to, sufficient, is, squeeze, even, do,
# Nearest to as: the, in, a, and, such, is, of, most,
# Nearest to institute: technology, roslin, elkhart, racket, postgraduate, stavropol, research, universities,
# Nearest to experience: worldly, ruska, pasture, sensations, milder, psychotherapy, amiens, preparation,
# Nearest to writers: novelists, fiction, winners, polymaths, secretive, dramatists, nebula, vig,
# Nearest to older: age, householder, alone, median, females, size, couples, households,
# Nearest to consists: each, archaebacteria, finalized, divided, magisterial, invalidated, barrington, jumper,
# Nearest to event: events, organize, incomplete, tendencies, start, aural, glaciations, donner,
# Nearest to egypt: nubia, ancient, egyptologist, narmer, cairo, giza, curator, ike,
# Nearest to applications: wilber, vtol, smarteiffel, italic, conductivity, evaluates, semiconductors, energetics,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8529 0.0245 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8158 0.0248 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9300 0.0239 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8727 0.0236 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9022 0.0228 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8242 0.0237 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7883 0.0237 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8470 0.0242 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7766 0.0244 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8418 0.0240 sec/batch
# Nearest to there: are, is, if, not, have, every, no, thereof,
# Nearest to has: been, in, is, as, and, some, an, several,
# Nearest to a: in, the, is, and, of, for, with, an,
# Nearest to most: the, as, in, is, during, are, by, well,
# Nearest to only: not, all, as, is, in, the, but, first,
# Nearest to be: is, or, but, a, it, to, if, example,
# Nearest to so: it, to, not, is, squeeze, sufficient, even, crystallized,
# Nearest to as: the, in, and, a, most, such, of, both,
# Nearest to institute: technology, roslin, elkhart, racket, stavropol, postgraduate, research, universities,
# Nearest to experience: ruska, psychotherapy, sensations, worldly, gebhard, dhyana, rainbows, preparation,
# Nearest to writers: novelists, fiction, winners, polymaths, dramatists, secretive, nebula, imposing,
# Nearest to older: age, householder, alone, median, females, size, couples, someone,
# Nearest to consists: magisterial, main, each, divided, archaebacteria, invalidated, finalized, consisting,
# Nearest to event: events, organize, tendencies, incomplete, start, webcast, donner, aural,
# Nearest to egypt: nubia, ancient, egyptologist, giza, narmer, cairo, lydians, curator,
# Nearest to applications: wilber, vtol, conductivity, italic, smarteiffel, semiconductors, evaluates, energetics,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8563 0.0245 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8586 0.0244 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
